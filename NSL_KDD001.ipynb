# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
with open('/content/drive/MyDrive/Colab Notebooks/PRCO304HK deep learning for ids/kddcup.names', 'r') as infile:
    kdd_names = infile.readlines()
kdd_cols = [x.split(':')[0] for x in kdd_names[1:]]
kdd_cols += ['class', 'difficulty']

# %%
kdd = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PRCO304HK deep learning for ids/KDDTrain+.txt', names=kdd_cols)
kdd_t = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PRCO304HK deep learning for ids/KDDTest+.txt', names=kdd_cols)

kdd.head()
# Out:
#    duration protocol_type  ...    class difficulty
# 0         0           tcp  ...   normal         20
# 1         0           udp  ...   normal         15
# 2         0           tcp  ...  neptune         19
# 3         0           tcp  ...   normal         21
# 4         0           tcp  ...   normal         21
#
# [5 rows x 43 columns]

# %%
kdd_cols = [kdd.columns[0]] + sorted(list(set(kdd.protocol_type.values))) + sorted(list(set(kdd.service.values))) + sorted(list(set(kdd.flag.values))) + kdd.columns[4:].tolist()

attack_map = [x.strip().split() for x in open('/content/drive/MyDrive/Colab Notebooks/PRCO304HK deep learning for ids/training_attack_types', 'r')]
attack_map = {k:v for (k,v) in attack_map}

attack_map
# Out:
# {'apache2': 'dos',
#  'arppoison': 'dos',
#  'back': 'dos',
#  'buffer_overflow': 'u2r',
#  'casesen': 'u2r',
#  'crashiis': 'dos',
#  'desnuke': 'dos',
#  'dict': 'r2l',
#  'eject': 'u2r',
#  'fdformat': 'u2r',
#  'ffbconfig': 'u2r',
#  'framespoof': 'r2l',
#  'ftp_write': 'r2l',
#  'ftpwrite': 'r2l',
#  'guess_passwd': 'r2l',
#  'guest': 'r2l',
#  'httptunnel': 'r2l',
#  'illegal-sniffer': 'probe',
#  'imap': 'r2l',
#  'ipsweep': 'probe',
#  'land': 'dos',
#  'loadmodule': 'u2r',
#  'lsdomain': 'probe',
#  'mailbomb': 'dos',
#  'mscan': 'probe',
#  'msscan': 'probe',
#  'multihop': 'r2l',
#  'named': 'r2l',
#  'ncftp': 'r2l',
#  'neptune': 'dos',
#  'netbus': 'r2l',
#  'netcat': 'r2l',
#  'nmap': 'probe',
#  'ntfsdos': 'u2r',
#  'ntinfoscan': 'probe',
#  'nukepw': 'u2r',
#  'perl': 'u2r',
#  'phf': 'r2l',
#  'pod': 'dos',
#  'portsweep': 'probe',
#  'ppmacro': 'r2l',
#  'processtable': 'dos',
#  'ps': 'u2r',
#  'queso': 'probe',
#  'rootkit': 'u2r',
#  'saint': 'probe',
#  'satan': 'probe',
#  'sechole': 'u2r',
#  'secret': 'u2r',
#  'selfping': 'dos',
#  'sendmail': 'r2l',
#  'smurf': 'dos',
#  'snmpget': 'r2l',
#  'snmpgetattack': 'r2l',
#  'snmpguess': 'r2l',
#  'spy': 'r2l',
#  'sqlattack': 'u2r',
#  'sshtrojan': 'r2l',
#  'syslogd': 'dos',
#  'teardrop': 'dos',
#  'tepreset': 'dos',
#  'ucpstorm': 'dos',
#  'udpstorm': 'dos',
#  'warezclient': 'r2l',
#  'warezmaster': 'r2l',
#  'worm': 'r2l',
#  'xlock': 'r2l',
#  'xsnoop': 'r2l',
#  'xterm': 'u2r',
#  'yaga': 'u2r'}

# %%
kdd['class'] = kdd['class'].replace(attack_map)
kdd_t['class'] = kdd_t['class'].replace(attack_map)

def cat_encode(df, col):
    return pd.concat([df.drop(col, axis=1), pd.get_dummies(df[col].values)], axis=1)


def log_trns(df, col):
    return df[col].apply(np.log1p)

cat_lst = ['protocol_type', 'service', 'flag']
for col in cat_lst:
    kdd = cat_encode(kdd, col)
    kdd_t = cat_encode(kdd_t, col)
    
log_lst = ['duration', 'src_bytes', 'dst_bytes']
for col in log_lst:
    kdd[col] = log_trns(kdd, col)
    kdd_t[col] = log_trns(kdd_t, col)
    
kdd = kdd[kdd_cols]
for col in kdd_cols:
    if col not in kdd_t.columns:
        kdd_t[col] = 0
kdd_t = kdd_t[kdd_cols]

kdd.head()
# Out:
#    duration  icmp  tcp  ...  dst_host_srv_rerror_rate   class  difficulty
# 0       0.0     0    1  ...                      0.00  normal          20
# 1       0.0     0    0  ...                      0.00  normal          15
# 2       0.0     0    1  ...                      0.00     dos          19
# 3       0.0     0    1  ...                      0.01  normal          21
# 4       0.0     0    1  ...                      0.00  normal          21
#
# [5 rows x 124 columns]

# %%
difficulty = kdd.pop('difficulty')
target = kdd.pop('class')
y_diff = kdd_t.pop('difficulty')
y_test = kdd_t.pop('class')

target = pd.get_dummies(target)
y_test = pd.get_dummies(y_test)

target

y_test

target = target.values
train = kdd.values
test = kdd_t.values
y_test = y_test.values

min_max_scaler = MinMaxScaler()
train = min_max_scaler.fit_transform(train)
test = min_max_scaler.transform(test)

train.shape

for idx, col in enumerate(list(kdd.columns)):
    print(idx, col)
# Out:
# 0 duration
# 1 icmp
# 2 tcp
# 3 udp
# 4 IRC
# 5 X11
# 6 Z39_50
# 7 aol
# 8 auth
# 9 bgp
# 10 courier
# 11 csnet_ns
# 12 ctf
# 13 daytime
# 14 discard
# 15 domain
# 16 domain_u
# 17 echo
# 18 eco_i
# 19 ecr_i
# 20 efs
# 21 exec
# 22 finger
# 23 ftp
# 24 ftp_data
# 25 gopher
# 26 harvest
# 27 hostnames
# 28 http
# 29 http_2784
# 30 http_443
# 31 http_8001
# 32 imap4
# 33 iso_tsap
# 34 klogin
# 35 kshell
# 36 ldap
# 37 link
# 38 login
# 39 mtp
# 40 name
# 41 netbios_dgm
# 42 netbios_ns
# 43 netbios_ssn
# 44 netstat
# 45 nnsp
# 46 nntp
# 47 ntp_u
# 48 other
# 49 pm_dump
# 50 pop_2
# 51 pop_3
# 52 printer
# 53 private
# 54 red_i
# 55 remote_job
# 56 rje
# 57 shell
# 58 smtp
# 59 sql_net
# 60 ssh
# 61 sunrpc
# 62 supdup
# 63 systat
# 64 telnet
# 65 tftp_u
# 66 tim_i
# 67 time
# 68 urh_i
# 69 urp_i
# 70 uucp
# 71 uucp_path
# 72 vmnet
# 73 whois
# 74 OTH
# 75 REJ
# 76 RSTO
# 77 RSTOS0
# 78 RSTR
# 79 S0
# 80 S1
# 81 S2
# 82 S3
# 83 SF
# 84 SH
# 85 src_bytes
# 86 dst_bytes
# 87 land
# 88 wrong_fragment
# 89 urgent
# 90 hot
# 91 num_failed_logins
# 92 logged_in
# 93 num_compromised
# 94 root_shell
# 95 su_attempted
# 96 num_root
# 97 num_file_creations
# 98 num_shells
# 99 num_access_files
# 100 num_outbound_cmds
# 101 is_host_login
# 102 is_guest_login
# 103 count
# 104 srv_count
# 105 serror_rate
# 106 srv_serror_rate
# 107 rerror_rate
# 108 srv_rerror_rate
# 109 same_srv_rate
# 110 diff_srv_rate
# 111 srv_diff_host_rate
# 112 dst_host_count
# 113 dst_host_srv_count
# 114 dst_host_same_srv_rate
# 115 dst_host_diff_srv_rate
# 116 dst_host_same_src_port_rate
# 117 dst_host_srv_diff_host_rate
# 118 dst_host_serror_rate
# 119 dst_host_srv_serror_rate
# 120 dst_host_rerror_rate
# 121 dst_host_srv_rerror_rate

# %%
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Activation, Reshape, Dropout
from keras.layers.embeddings import Embedding

def build_network():

    models = []
    model = Sequential()
    model.add(Dense(64, input_dim=122))

    model.add(Dense(32))
    model.add(Activation('relu'))
    model.add(Dropout(.15))
    model.add(Dense(32))
    model.add(Activation('relu'))
    model.add(Dropout(.15))
    model.add(Dense(32))
    model.add(Activation('relu'))
    model.add(Dropout(.15))
    model.add(Dense(5))
    model.add(Activation('softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

# %%
NN = build_network()
early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=3, verbose=0, mode='auto')


NN.fit(x=train, y=target, epochs=100, validation_split=0.1, batch_size=128, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 886/886 [==============================] - 3s 3ms/step - loss: 0.3912 - accuracy: 0.8685 - val_loss: 0.0346 - val_accuracy: 0.9873
# Epoch 2/100
# 886/886 [==============================] - 2s 2ms/step - loss: 0.0396 - accuracy: 0.9862 - val_loss: 0.0246 - val_accuracy: 0.9935
# Epoch 3/100
# 886/886 [==============================] - 2s 2ms/step - loss: 0.0297 - accuracy: 0.9914 - val_loss: 0.0237 - val_accuracy: 0.9942
# Epoch 4/100
# 886/886 [==============================] - 2s 2ms/step - loss: 0.0243 - accuracy: 0.9928 - val_loss: 0.0194 - val_accuracy: 0.9945
# Epoch 5/100
# 886/886 [==============================] - 2s 2ms/step - loss: 0.0221 - accuracy: 0.9936 - val_loss: 0.0206 - val_accuracy: 0.9952
# Epoch 6/100
# 886/886 [==============================] - 2s 3ms/step - loss: 0.0213 - accuracy: 0.9941 - val_loss: 0.0163 - val_accuracy: 0.9956
# Epoch 7/100
# 886/886 [==============================] - 2s 2ms/step - loss: 0.0183 - accuracy: 0.9946 - val_loss: 0.0165 - val_accuracy: 0.9963
# Epoch 8/100
# 886/886 [==============================] - 2s 2ms/step - loss: 0.0166 - accuracy: 0.9953 - val_loss: 0.0169 - val_accuracy: 0.9955
# Epoch 9/100
# 886/886 [==============================] - 2s 2ms/step - loss: 0.0168 - accuracy: 0.9950 - val_loss: 0.0138 - val_accuracy: 0.9962
# Epoch 10/100
# 886/886 [==============================] - 2s 2ms/step - loss: 0.0152 - accuracy: 0.9953 - val_loss: 0.0156 - val_accuracy: 0.9958
# Epoch 11/100
# 886/886 [==============================] - 2s 3ms/step - loss: 0.0157 - accuracy: 0.9954 - val_loss: 0.0122 - val_accuracy: 0.9970
# Epoch 12/100
# 886/886 [==============================] - 2s 2ms/step - loss: 0.0150 - accuracy: 0.9955 - val_loss: 0.0112 - val_accuracy: 0.9976
# Epoch 13/100
# 886/886 [==============================] - 2s 3ms/step - loss: 0.0125 - accuracy: 0.9965 - val_loss: 0.0128 - val_accuracy: 0.9969
# Epoch 14/100
# 886/886 [==============================] - 2s 2ms/step - loss: 0.0146 - accuracy: 0.9953 - val_loss: 0.0109 - val_accuracy: 0.9971
# Epoch 15/100
# 886/886 [==============================] - 2s 3ms/step - loss: 0.0137 - accuracy: 0.9961 - val_loss: 0.0118 - val_accuracy: 0.9972
# Epoch 16/100
# 886/886 [==============================] - 2s 2ms/step - loss: 0.0129 - accuracy: 0.9962 - val_loss: 0.0113 - val_accuracy: 0.9975
# Epoch 17/100
# 886/886 [==============================] - 2s 3ms/step - loss: 0.0136 - accuracy: 0.9962 - val_loss: 0.0111 - val_accuracy: 0.9971

# %%
from sklearn.metrics import confusion_matrix
preds = NN.predict(test)
pred_lbls = np.argmax(preds, axis=1)
true_lbls = np.argmax(y_test, axis=1)

NN.evaluate(test, y_test)

confusion_matrix(true_lbls, pred_lbls)
# Out:
# 705/705 [==============================] - 1s 1ms/step - loss: 2.5502 - accuracy: 0.7742
# array([[5884, 1489,   82,    3,    0],
#        [  90, 9404,  213,    2,    2],
#        [ 262,  317, 1802,   38,    2],
#        [   2, 2525,    7,  353,    0],
#        [   1,   47,    0,    9,   10]])

# %%
from sklearn.metrics import f1_score
f1_score(true_lbls, pred_lbls, average='weighted')
# Out:
# 0.7428145065018996
